# %%
#!unzip -nq /datasets/minispeechcommands/msc-train.zip
#!unzip -nq /datasets/minispeechcommands/msc-val.zip
#!unzip -nq /datasets/minispeechcommands/msc-test.zip

# %%
import tensorflow as tf
import os
import numpy as np
import random
import tensorflow_io as tfio
import preprocessing as pr


seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(seed)
tf.random.set_seed(seed)
np.random.seed(seed)
# Out:
# 2022-12-20 16:20:30.527810: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-20 16:20:30.637654: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-20 16:20:30.642252: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-20 16:20:30.642268: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-20 16:20:30.666200: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-20 16:20:31.556926: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-20 16:20:31.556985: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-20 16:20:31.556991: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 31
# 2022-12-20 16:20:33.342916: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-12-20 16:20:33.342944: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-20 16:20:33.342957: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-1a21d5cf-232d-49da-b53d-f1e5025e08e5): /proc/driver/nvidia/version does not exist
# 2022-12-20 16:20:33.343210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Define Hyper-Parameters

# %% [markdown]
# ## Create Train/Val/Test Datasets

# %%
train_ds = tf.data.Dataset.list_files(['msc-train/go*', 'msc-train/stop*'])
val_ds = tf.data.Dataset.list_files(['msc-val/go*', 'msc-val/stop*'])
test_ds = tf.data.Dataset.list_files(['msc-test/go*', 'msc-test/stop*'])

# %%
batch_size = pr.TRAINING_ARGS['batch_size']
epochs = pr.TRAINING_ARGS['epochs']

train_ds = train_ds.map(pr.preprocess).batch(batch_size).cache()
val_ds = val_ds.map(pr.preprocess).batch(batch_size)
test_ds = test_ds.map(pr.preprocess).batch(batch_size)

# %%
for example_batch, example_labels in train_ds.take(1):
  print('Batch Shape:', example_batch.shape)
  print('Data Shape:', example_batch.shape[1:])
  print('Labels:', example_labels)
# Out:
# Batch Shape: (32, 31, 31, 1)
# Data Shape: (31, 31, 1)
# Labels: tf.Tensor([1 5 1 5 5 1 5 1 5 1 5 5 1 5 5 1 1 5 1 1 5 1 5 5 5 1 5 1 1 5 5 5], shape=(32,), dtype=int64)
# 2022-12-20 16:20:34.334684: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Create the Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=example_batch.shape[1:]),
    tf.keras.layers.Conv2D(filters=int(128 * pr.alpha), kernel_size=[3, 3], strides=[2, 2],
        use_bias=False, padding='valid'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Conv2D(filters=int(128 * pr.alpha), kernel_size=[3, 3], strides=[1, 1],
        use_bias=False, padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Conv2D(filters=int(128 * pr.alpha), kernel_size=[3, 3], strides=[1, 1],
        use_bias=False, padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(units=len(pr.LABELS)),
    tf.keras.layers.Softmax()
])

# %%
import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

begin_step = int(len(train_ds) * epochs * 0.2)
end_step = int(len(train_ds) * epochs)

pruning_params = {
    'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(
        initial_sparsity=0.40,
        final_sparsity=pr.final_sparsity,
        begin_step=begin_step,
        end_step=end_step
    )
}

model_for_pruning = prune_low_magnitude(model, **pruning_params)

#model_for_pruning.summary()

# %% [markdown]
# ## Train the Model

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=False)
initial_learning_rate = pr.TRAINING_ARGS['initial_learning_rate']
end_learning_rate = pr.TRAINING_ARGS['end_learning_rate']

linear_decay = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=initial_learning_rate,
    end_learning_rate=end_learning_rate,
    decay_steps=len(train_ds) * epochs,
)
optimizer = tf.optimizers.Adam(learning_rate=linear_decay)
metrics = [tf.metrics.SparseCategoricalAccuracy()]
callbacks = [tfmot.sparsity.keras.UpdatePruningStep()]
model_for_pruning.compile(loss=loss, optimizer=optimizer, metrics=metrics)

history = model_for_pruning.fit(train_ds, epochs=epochs, validation_data=val_ds,callbacks=callbacks)
# Out:
# Epoch 1/70
# 50/50 [==============================] - 8s 104ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.6888 - val_loss: 2.4222 - val_sparse_categorical_accuracy: 0.5200
# Epoch 2/70
# 50/50 [==============================] - 2s 51ms/step - loss: 0.3543 - sparse_categorical_accuracy: 0.8600 - val_loss: 4.1606 - val_sparse_categorical_accuracy: 0.5200
# Epoch 3/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.3416 - sparse_categorical_accuracy: 0.8600 - val_loss: 2.5428 - val_sparse_categorical_accuracy: 0.5500
# Epoch 4/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.2892 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.4794 - val_sparse_categorical_accuracy: 0.8450
# Epoch 5/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.2096 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3702 - val_sparse_categorical_accuracy: 0.8550
# Epoch 6/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.1783 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.2561 - val_sparse_categorical_accuracy: 0.9150
# Epoch 7/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.1504 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.2656 - val_sparse_categorical_accuracy: 0.8950
# Epoch 8/70
# 50/50 [==============================] - 2s 48ms/step - loss: 0.1567 - sparse_categorical_accuracy: 0.9413 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9150
# Epoch 9/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9475 - val_loss: 0.3319 - val_sparse_categorical_accuracy: 0.9100
# Epoch 10/70
# 50/50 [==============================] - 2s 48ms/step - loss: 0.1183 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.3001 - val_sparse_categorical_accuracy: 0.9250
# Epoch 11/70
# 50/50 [==============================] - 3s 51ms/step - loss: 0.1116 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.2794 - val_sparse_categorical_accuracy: 0.9350
# Epoch 12/70
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0948 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.2758 - val_sparse_categorical_accuracy: 0.9200
# Epoch 13/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0874 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3187 - val_sparse_categorical_accuracy: 0.9300
# Epoch 14/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.3026 - val_sparse_categorical_accuracy: 0.9200
# Epoch 15/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.2775 - val_sparse_categorical_accuracy: 0.9350
# Epoch 16/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9700 - val_loss: 0.2618 - val_sparse_categorical_accuracy: 0.9350
# Epoch 17/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.2543 - val_sparse_categorical_accuracy: 0.9400
# Epoch 18/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0613 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.2043 - val_sparse_categorical_accuracy: 0.9500
# Epoch 19/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0536 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.3251 - val_sparse_categorical_accuracy: 0.9300
# Epoch 20/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.2410 - val_sparse_categorical_accuracy: 0.9600
# Epoch 21/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0546 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.2574 - val_sparse_categorical_accuracy: 0.9300
# Epoch 22/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0506 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1954 - val_sparse_categorical_accuracy: 0.9700
# Epoch 23/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.2784 - val_sparse_categorical_accuracy: 0.9550
# Epoch 24/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0511 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.2711 - val_sparse_categorical_accuracy: 0.9600
# Epoch 25/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9812 - val_loss: 6.4210 - val_sparse_categorical_accuracy: 0.5200
# Epoch 26/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.2858 - val_sparse_categorical_accuracy: 0.9450
# Epoch 27/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.3567 - val_sparse_categorical_accuracy: 0.9500
# Epoch 28/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.5330 - val_sparse_categorical_accuracy: 0.8850
# Epoch 29/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.7300 - val_sparse_categorical_accuracy: 0.8250
# Epoch 30/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.9691 - val_sparse_categorical_accuracy: 0.7500
# Epoch 31/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.3685 - val_sparse_categorical_accuracy: 0.9300
# Epoch 32/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.5594 - val_sparse_categorical_accuracy: 0.8800
# Epoch 33/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.6717 - val_sparse_categorical_accuracy: 0.8700
# Epoch 34/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.9400
# Epoch 35/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.4179 - val_sparse_categorical_accuracy: 0.9300
# Epoch 36/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.6000 - val_sparse_categorical_accuracy: 0.8850
# Epoch 37/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.5166 - val_sparse_categorical_accuracy: 0.8950
# Epoch 38/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0235 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.5521 - val_sparse_categorical_accuracy: 0.8950
# Epoch 39/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.4462 - val_sparse_categorical_accuracy: 0.9100
# Epoch 40/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.4530 - val_sparse_categorical_accuracy: 0.9100
# Epoch 41/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.4472 - val_sparse_categorical_accuracy: 0.9200
# Epoch 42/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.4799 - val_sparse_categorical_accuracy: 0.9050
# Epoch 43/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.4269 - val_sparse_categorical_accuracy: 0.9200
# Epoch 44/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.9350
# Epoch 45/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.4449 - val_sparse_categorical_accuracy: 0.9250
# Epoch 46/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.4544 - val_sparse_categorical_accuracy: 0.9250
# Epoch 47/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.5634 - val_sparse_categorical_accuracy: 0.9200
# Epoch 48/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.6120 - val_sparse_categorical_accuracy: 0.9050
# Epoch 49/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.6124 - val_sparse_categorical_accuracy: 0.9100
# Epoch 50/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.5779 - val_sparse_categorical_accuracy: 0.9150
# Epoch 51/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.5424 - val_sparse_categorical_accuracy: 0.9200
# Epoch 52/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.5903 - val_sparse_categorical_accuracy: 0.9150
# Epoch 53/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.8502 - val_sparse_categorical_accuracy: 0.9000
# Epoch 54/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.7107 - val_sparse_categorical_accuracy: 0.8950
# Epoch 55/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0215 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.6099 - val_sparse_categorical_accuracy: 0.9100
# Epoch 56/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.5199 - val_sparse_categorical_accuracy: 0.9300
# Epoch 57/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.4807 - val_sparse_categorical_accuracy: 0.9400
# Epoch 58/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.4264 - val_sparse_categorical_accuracy: 0.9400
# Epoch 59/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.3453 - val_sparse_categorical_accuracy: 0.9400
# Epoch 60/70
# 50/50 [==============================] - 2s 49ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.9650
# Epoch 61/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.2718 - val_sparse_categorical_accuracy: 0.9600
# Epoch 62/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.2764 - val_sparse_categorical_accuracy: 0.9700
# Epoch 63/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 0.9700
# Epoch 64/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.9700
# Epoch 65/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.2745 - val_sparse_categorical_accuracy: 0.9700
# Epoch 66/70
# 50/50 [==============================] - 2s 50ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2764 - val_sparse_categorical_accuracy: 0.9700
# Epoch 67/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2785 - val_sparse_categorical_accuracy: 0.9700
# Epoch 68/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2804 - val_sparse_categorical_accuracy: 0.9650
# Epoch 69/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2822 - val_sparse_categorical_accuracy: 0.9650
# Epoch 70/70
# 50/50 [==============================] - 2s 47ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.2837 - val_sparse_categorical_accuracy: 0.9550

# %%
test_loss, test_accuracy = model_for_pruning.evaluate(test_ds)

training_loss = history.history['loss'][-1]
training_accuracy = history.history['sparse_categorical_accuracy'][-1]
val_loss = history.history['val_loss'][-1]
val_accuracy = history.history['val_sparse_categorical_accuracy'][-1]

print(f'Training Loss: {training_loss:.4f}')
print(f'Training Accuracy: {training_accuracy*100.:.2f}%')
print()
print(f'Validation Loss: {val_loss:.4f}')
print(f'Validation Accuracy: {val_accuracy*100.:.2f}%')
print()
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy*100.:.2f}%')
# Out:
# 7/7 [==============================] - 1s 50ms/step - loss: 0.0850 - sparse_categorical_accuracy: 0.9800
# Training Loss: 0.0086
# Training Accuracy: 99.69%
#
# Validation Loss: 0.2837
# Validation Accuracy: 95.50%
#
# Test Loss: 0.0850
# Test Accuracy: 98.00%

# %% [markdown]
# ## TF model save

# %%
from time import time

timestamp = int(time())
modelName = 'model13'

saved_model_dir = f'./saved_models/{modelName}'
if not os.path.exists(saved_model_dir):
    os.makedirs(saved_model_dir)
model.save(saved_model_dir)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./saved_models/model13/assets
# INFO:tensorflow:Assets written to: ./saved_models/model13/assets

# %% [markdown]
# ## TF convert

# %%
MODEL_NAME = modelName

converter = tf.lite.TFLiteConverter.from_saved_model(f'./saved_models/{MODEL_NAME}')
tflite_model = converter.convert()
tflite_models_dir = './tflite_models'
if not os.path.exists(tflite_models_dir):
    os.makedirs(tflite_models_dir)
tflite_model_name = os.path.join(tflite_models_dir, f'{MODEL_NAME}.tflite')
tflite_model_name
with open(tflite_model_name, 'wb') as fp:
    fp.write(tflite_model)

import zipfile

with zipfile.ZipFile(f'{tflite_model_name}.zip', 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(tflite_model_name)

pruned_tflite_size = os.path.getsize(tflite_model_name) / 1024
pruned_zip_size = os.path.getsize(f'{tflite_model_name}.zip') / 1024

print(f'Original TFLite Size (pruned model): {pruned_tflite_size:.2f} KB')
print(f'ZIP TFLite Size (pruned model): {pruned_zip_size:.2f} KB')
# Out:
# Original TFLite Size (pruned model): 24.73 KB
# ZIP TFLite Size (pruned model): 14.07 KB
# 2022-12-20 16:23:29.619184: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-12-20 16:23:29.619235: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2022-12-20 16:23:29.619809: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: ./saved_models/model13
# 2022-12-20 16:23:29.623075: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2022-12-20 16:23:29.623110: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: ./saved_models/model13
# 2022-12-20 16:23:29.627976: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-12-20 16:23:29.629171: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2022-12-20 16:23:29.660557: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: ./saved_models/model13
# 2022-12-20 16:23:29.670084: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 50277 microseconds.
# 2022-12-20 16:23:29.688178: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
#!ls ./tflite_models/

# %%
#use the zipped model we have
#with zipfile.ZipFile("./tflite_models/{tflite_model_name}.zip", 'r') as zip_ref:
#    zip_ref.extractall("./tflite_models/zipped/")

# %%
interpreter = tf.lite.Interpreter(model_path=f'./tflite_models/{MODEL_NAME}.tflite')
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print('Number of inputs:', len(input_details))
print('Input name:', input_details[0]['name'])
print('Input index:', input_details[0]['index'])
print('Number of output:', len(output_details))
print('Output name:', output_details[0]['name'])
print('Output index:', output_details[0]['index'])
# Out:
# Number of inputs: 1
# Input name: serving_default_input_1:0
# Input index: 0
# Number of output: 1
# Output name: StatefulPartitionedCall:0
# Output index: 15
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
from glob import glob

filenames = glob('msc-test/go*') + glob('msc-test/stop*')
print(len(filenames))
# Out:
# 200

# %%
from time import time


avg_preprocessing_latency = 0
avg_model_latency = 0
latencies = []
accuracy = 0.0

for filename in filenames:
    audio_binary = tf.io.read_file(filename)

    # NEED ONLY FOR TESTING
    path_parts = tf.strings.split(filename, '/')
    path_end = path_parts[-1]
    file_parts = tf.strings.split(path_end, '_')
    true_label = file_parts[0]
    true_label = true_label.numpy().decode()

    # PRE-PROCESSING (LOG-MEL SPECTROGRAM)
    start_preprocess = time()
    audio, sampling_rate = tf.audio.decode_wav(audio_binary)
    audio = tf.squeeze(audio)

    zero_padding = tf.zeros(sampling_rate - tf.shape(audio), dtype=tf.float32)
    audio_padded = tf.concat([audio, zero_padding], axis=0)

    if pr.downsampling_rate != sampling_rate:
        audio_padded = tfio.audio.resample(audio_padded, sampling_rate_int64, downsampling_rate)

    stft = tf.signal.stft(
        audio_padded,
        frame_length=pr.frame_length,
        frame_step=pr.frame_step,
        fft_length=pr.frame_length
    )
    spectrogram = tf.abs(stft)
    mel_spectrogram = tf.matmul(spectrogram, pr.linear_to_mel_weight_matrix)
    log_mel_spectrogram = tf.math.log(mel_spectrogram + 1.e-6)
    log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, 0)  # batch axis
    log_mel_spectrogram = tf.expand_dims(log_mel_spectrogram, -1)  # channel axis
    mfcss = tf.signal.mfccs_from_log_mel_spectrograms(log_mel_spectrogram)
    end_preprocess = time()
    interpreter.set_tensor(input_details[0]['index'], mfcss)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    end_inference = time()

    top_index = np.argmax(output[0])
    predicted_label = pr.LABELS[top_index]

    accuracy += true_label == predicted_label
    avg_preprocessing_latency += (end_preprocess - start_preprocess)
    avg_model_latency += (end_inference - end_preprocess)
    latencies.append(end_inference - start_preprocess)

# %%
accuracy /= len(filenames)
avg_preprocessing_latency /= len(filenames)
avg_model_latency /= len(filenames)
total_latency = np.median(latencies)

import os

model_size = os.path.getsize(f'./tflite_models/{MODEL_NAME}.tflite')

print(f'Accuracy: {accuracy * 100.:.3f}%')
print(f'Original TFLite Model size: {model_size / 1024:.1f} KB')
print(f'Preprocessing Latency: {1000 * avg_preprocessing_latency:.1f} ms')
print(f'Model Latency: {1000 * avg_model_latency:.1f} ms')
print(f'Total Latency: {1000 * total_latency:.1f} ms')
# Out:
# Accuracy: 98.000%
# Original TFLite Model size: 24.7 KB
# Preprocessing Latency: 4.7 ms
# Model Latency: 0.1 ms
# Total Latency: 4.8 ms

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1a21d5cf-232d-49da-b53d-f1e5025e08e5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
